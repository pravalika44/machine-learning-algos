# %% [markdown]
# ## WHAT IS MACHINE LEARNING

# %% [raw]
# Machine learning is a field of study that gives computers the ability to learn without being explicitly programmed
#
# Machine learning is the sub-set of artificial intelligence
#
# We use Ml algorithms to train on some data and then use it to test the data by giving some predictions
#
# Three different types of learning
#
# 1) supervised learning
# - here the data is labelled, which means the data will have distinct features
# - so predictions will be made on labelled data
# - we will pass the input data and output data, so model will be trained with both input and output data
# -  predictions will be made on the output data
#
# 2) unsupervised learning
# - here data is unlabelled
# - and here we only pass input data so model will be trained only with the input data
# - example is spam detection
#
# 3) reinforcement learning
# - neither input nor output data will be passed
# - we just show the model how to do by providing the steps and the model learns on itself
#
# - we will only be learning supervised and unsupervised learning in this module
# - because reinforcement learning itself is a j=huge topic

# %% [markdown]
# ## SUPERVISED M.L. ALGORITHMS
#
# - 1) regression
# - 2) classification

# %% [markdown]
# ## REGRESSION
# - regression searches for relationships amoung variables

# %% [markdown]
# ### example
# - factors effecting the salary may be working hours, experience, job role, education level, previous job role
# - here the factors effecting the salary are the independent variables or independent features or input
# - and the salary is the dependent variable or dependent feature or ouput or target variable
# -
# - regression algorithm will look for a linear relationship between the independent variables and the target variable and predict the the value for the target variable
# -
# - the more data we pass to the algorithm the more accurate the predicted output will be

# %% [markdown]
# ## how to identify if it is a regression task
# - if the target variable is a numerical continous value then we need to use the regression algorithm

# %% [markdown]
# ## A) LINEAR REGRESSION
# - widely used
# - easy to use
# -
# - linear regression is a supervised machine learning alogorithm (if asked in a interview begin with this statement)
# - it studies the linear relationship between the input and output data
# - it works on a line equation y=mx+c
# - the task of the linear regression is to best fit line that fits the data
# - the line that gives the least error is considerd as the best fit line

# %% [markdown]
# ## IMP NOTE
# - linear regression only works on regression problem, it does not work on classification problems
# - classification problems or predictions as in yes or no, true or false,  or 2
# - it works on regression problems as in predcting the sales, predcting the count
# - when we are trying to predict on continous values its called as regression

# %% [markdown]
# ## cost function
# - cost function represents the error value
# - in simple words the error is actual value-predicted value
# - algorithm will caluculate the cost function for each line, based on the value of cost function the algorithm will select the line with least cost function
# -
# - for cost function formula see notes
# - y=x is the line equation for actual data
# - and y=mx for predicted data

# %% [markdown]
# ## Linear Regression
# - ML Algorithm based on supervised learning is commonly used for predictive analysis.
# - Used to determine the linear relationship between the dependent variable (y) and independent variable (x). This linear relationship is represented by a straight line called regression line / best-fit line. This line is the pattern on which the machine has learned from the data.
# - Used for predicting the output of quantitative type (continuous value) eg. Age, salary, price etc.
#
# ##### Simple Linear Regression:
# - one X variable and one Y variable
# - Formula: **y = mx + c**
#         y is the response or target variable
#         x is the predictor variable
#         m is the coefficient of x
#         c is the intercept
#
#
# ##### Multiple Linear Regression:
# - one Y variable and two or more X variable
# - Formula: **y = m1x1 + m2x2.....+ mnxn**
#         y is the target variable
#         x1, x2, x3..xn represents the features.
#         m1, m2, m3....mn are the coefficients of each feature ie., x1, x2, x3.. respectively.
#
#
# ## Cost Function
# * It is a function that signifies how much the predicted values are deviated from the actual values.<br>
# * MSE is the most commonly used cost function for Linear Regression. MSE is average of the sum of squared difference between the predicted and actual value. Output of MSE is the single number representing the cost.
#
#
# # Gradient Descent
# * It is an optimization algorithm used for minimizing the cost function. It's based on a convex function and tweaks its parameters iteratively to minimize a given function to its global minimum. It helps to get optimal value for the slope m which provides the best fit line.<br>
# * Our aim is to minimize the error between the predicted values and the actual values.<br>
#
#
# * The gradient descent curve has the cost function and slope values. This algorithm intially starts with a randomnly selected m value and from there it uses calculus to iteratively adjust the values of m and calculate cost function for all the slopes. So it takes all the error value and search for minimum error.  Once it finds the m that has minimum error, it creates a best fit line using that m.
#
# * For the randomly selected m, it might not result in global minimum. So we need to move down and for that we use convergence theorem
#
# * Learning rate should be a small value ranging between 0.1 to 0.0000001.
#
# * To find the derivative of slope, we need to draw a tangent from that point.
#
# * If the right-hand side of the tangent is facing towards down then its a negative slope. So the derivative of that slope will also be negative. Hence we need to increase the m value to move towards the global minima.
#
# * If the right-hand side of the tangent faces towards the left, then its a positive slope. So the derivative of the slope will be positive. We need to reduce the m value so it will move towards the global minima.
#
# # $Model Evaluation $
#
# Model evaluation is very important in data science. It helps you to understand the performance of your model and makes it easy to present your model to other business people
#
# ### $R^2$ statistics
#
#
# R Square measures how much variability in dependent variable can be explained by the model. It is the square of the Correlation Coefficient(R) and that is why it is called R Square.
#
# The R-squared statistic provides a measure of fit. It takes the form of a proportion—the proportion of variance
# explained—and so it always takes on a value between 0 and 1.
# In simple words, it represents how much of our data is being explained by our model.
# For example,  $R^2$ statistic = 0.75, it says that our model fits 75 % of the total data set.
# Similarly, if it is 0, it means none of the data points is being explained and a value of 1 represents 100% data explanation.
# Mathematically $R^2$ statistic is calculated as :
# <img src="RSquared.PNG" width="300">
#
# Where RSS:  is  the Residual Sum of squares and is given as :
# <img src="RSS.PNG">
#
# RSS is the residual(error) term we have been talking about so far.
# And, TSS:  is  the Total sum of squares and given as :
# <img src="TSS.PNG">
#
# TSS is calculated when we consider the line passing through the mean value of y, to be the best fit line.
# Just like RSS, we calculate the error term when the best fit line is the line passing through the mean value of y and we get the value of TSS.
#     <img src="TSS2.PNG">
#
# The closer the value of R2 is to 1 the better the model fits our data. If R2 comes below 0(which is a possibility) that means the model is so bad that it is performing even worse than the average best fit line.
#
# R Square is calculated by the sum of squared of prediction error divided by the total sum of the square which replaces the calculated prediction with mean. R Square value is between 0 to 1 and a bigger value indicates a better fit between prediction and actual value.
#
#
# R Square is a good measure to determine how well the model fits the dependent variables. However, it does not take into consideration of overfitting problem. If your regression model has many independent variables, because the model is too complicated, it may fit very well to the training data but performs badly for testing data. That is why Adjusted R Square is introduced because it will penalize additional independent variables added to the model and adjust the metric to prevent overfitting issues.

# %% [markdown]
# ### Adjusted $R^2$ statistics
# As we increase the number of independent variables in our equation, the R2 increases as well. But that doesn’t mean that the new independent variables have any correlation with the output variable. In other words, even with the addition of new features in our model, it is not necessary that our model will yield better results but R2 value will increase. To rectify this problem, we use Adjusted R2 value which penalises excessive use of such features which do not correlate with the output data.
# Let’s understand this with an example:
#
# ![image-2.png](attachment:image-2.png)
# We can see that R2 always increases with an increase in the number of independent variables.
# Thus, it doesn’t give a better picture and so we need Adjusted R2 value to keep this in check.
# Mathematically, it is calculated as:
#                                         ![image.png](attachment:image.png)
# In the equation above, when p = 0, we can see that adjusted R2 becomes equal to R2.
# Thus, adjusted R2  will always be less than or equal to R2, and it penalises the excess of independent variables which do not affect the dependent variable.

# %% [markdown]
# ## $ Mean Square Error(MSE)/Root Mean Square Error(RMSE) $
#
# While R Square is a relative measure of how well the model fits dependent variables, Mean Square Error is an absolute measure of the goodness for the fit.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# MSE is calculated by the sum of square of prediction error which is real output minus predicted output and then divide by the number of data points. It gives you an absolute number on how much your predicted results deviate from the actual number. You cannot interpret many insights from one single result but it gives you a real number to compare against other model results and help you select the best regression model.
#
#
# Root Mean Square Error(RMSE) is the square root of MSE. It is used more commonly than MSE because firstly sometimes MSE value can be too big to compare easily. Secondly, MSE is calculated by the square of error, and thus square root brings it back to the same level of prediction error and makes it easier for interpretation.

# %% [markdown]
# ## $ Mean Absolute Error(MAE) $

# %% [raw]
# Mean Absolute Error(MAE) is similar to Mean Square Error(MSE). However, instead of the sum of square of error in MSE, MAE is taking the sum of the absolute value of error.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## STEP1 - Business Case and domain analysis
# - Prediction of Medical expenses

# %% [markdown]
# **Which Factors Influence the Price of Health Insurance?**
# Many factors that affect how much you pay for health insurance are not within your control. Nonetheless, it's good to have an understanding of what they are. Here are some factors that affect how much health insurance premiums cost
#
# ## domain analysis
# -  age: age of primary beneficiary
#
# -  sex: insurance contractor gender, female, male
#
# -  bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
#
# -  children: Number of children covered by health insurance / Number of dependents
#
# -  smoker: Smoking
#
# -  region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest

# %% [markdown]
# ## We start our analysis by importing necessary modules.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## loding the data into pandas dataframe

# %%
df=pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## STEP2 - BASIC CHECKS AND EXAMINING THE DATA

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.describe(include="O")
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# - we have no null values and missing values in the dataset
# - but we have 3 object columns to encode further

# %% [markdown]
# ## UNIQUE AND VALUE COUNTS

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.age.unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39], dtype=int64)

# %%
df.age.value_counts().head()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# Name: age, dtype: int64

# %%
df.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.sex.value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df.children.unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
df.children.value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.smoker.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# ## STEP3 - EDA EXPLORATORY DATA ANALYSIS
# - In this step we visualize data

# %% [markdown]
# - The obvious question that comes to mind is- how are age and medical charges related. I check for it in the plot shown below. If sex can have any influence on the relationship is also checked. As can be observed, we see 3 prominent, parallel lines like pattern. In all of the three, one can see an increase in charges with increasing age.`

# %%
sns.relplot(x='age', y='charges', data=df)
plt.title('Effect of Age on Charges')
plt.show()

# %%
sns.relplot(x='age', y='charges',hue='sex',data=df)
plt.title('Effect of Age on Charges with respect to gender')
plt.show()

# %%
#sns.relplot(x='age', y='charges', hue='sex',style='smoker',data=df, palette='husl')
sns.relplot(x='age', y='charges', col='sex',style='smoker',data=df)

# %%
sns.relplot(x='age', y='charges', col='children',data=df)
plt.show()

# %%
sns.relplot(x='age', y='charges', col='sex',style='region',data=df)

# %% [markdown]
# - Next, lets check if BMI has any influence on the medical charges. BMI as explained above is Body Mass Index. Higher BMI is correlated to higher body fat and thus, also correlated to metabolic diseases. BMI is thus a measure of body weight status. For adults, BMI below 18.5 is considered underweight, BMI of 18.5 – 24.9 is considered normal, BMI of 25.0 – 29.9 is considered overweight while BMI above 30 is considered obese. Therefore, I am interested to check if higher BMI can be correlated to higher medical charges.

# %% [markdown]
# - Although, in the first scatterplot (shown below) the influence of BMI on charges is not clearly visible. But, BMI's influence on medical charges become clear when I involve 'smoker' feature (second scatterplot shown below). It shows that increasing BMI combined with smoking leads to higher charges compared to non-smoker with a higher BMI. This indicates, a probable synergistic relationship between smoking and BMI.`

# %%
sns.scatterplot(x='bmi',y='charges',data=df)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.relplot(x='bmi',y='charges',col='sex',data=df)
plt.title('Effect of BMI on Charges')
plt.show()

# %%
sns.relplot(x='bmi',y='charges',col='children',data=df)

# %%
sns.relplot(x='bmi',y='charges',col='smoker',data=df)

# %%
sns.relplot(x='bmi',y='charges',col='region',data=df)

# %%
sns.relplot(x='bmi',y='charges',col='children',data=df)

# %%
sns.relplot(x='bmi',y='charges',hue='smoker',style='sex',data=df)

# %%
sns.catplot(x="children", y='charges', hue='smoker', kind='box',data=df, palette= 'Paired')

# %% [markdown]
# ## STEP4 -  DATA PREPROCESSING
# - here we handle null values and junk values
# - we handle outliers
# - and we handle categorical data. that is, we convert catogerical data to numerical data

# %% [markdown]
# ## IMP NOTE
# - this conversion of categorical to numerical is important because the machine(none of the algorithms) can understand categorical data
# - example
# - if the categorical data has two unique values(yes and no) we can make yes to 1 and no to 0

# %% [markdown]
# ## MISSING VALUES DETECTION AND HANDLING

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# - so there are no null values
# - so no need to handle null values
# - and there are no junk values

# %% [markdown]
# ## CHECKING FOR OUTLIERS AND HANDLING THEM

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## NOTE
# - as only and bmi are numerical continous, we can get outliers in only those columns

# %%
sns.boxplot(df.age)
plt.show()

# %% [markdown]
# - no outliers in the age column

# %%
sns.boxplot(df.bmi)
plt.show()

# %% [markdown]
# - there are outliers in case of bmi on the max side

# %% [markdown]
# ## HANDLING CATEGORICAL DATA

# %% [markdown]
# - Looking at the dtypes of the features (as done below), we find that we have 3 out of 7 features that have 'object' dtype.
# - These are - sex, smoker and region.
# - If we want to use them for predictive modelling then these need to be encoded .

# %% [markdown]
# ## METHOD 1 - LABEL ENCODING
#
# - For features that have just two unique values like in case of smoker and sex, we use Label Encoder
# - in label encoder method, the data is organised in alphebitical order and the first unique value will be assigned with 0 and the other with 1 and so on.

# %% [markdown]
# ## METHOD 2 - ONE HOT ENCODING
# - and for region we use one hot encoding .
# - One hot encoding is better than label encoding when we have more than two values for any categorical feature.
# - in one hot encoding

# %% [markdown]
# ## METHOD 3 - using get_dummies( ) function

# %%
df=pd.read_csv('insurance.csv')

# %% [markdown]
# ### handling region

# %%
df1=pd.get_dummies(df['region'],prefix='region',drop_first=True)
df= pd.concat([df,df1], axis=1).drop(['region'],axis=1)
df.head()
# Out:
#    age     sex     bmi  children smoker      charges  region_northwest  \
# 0   19  female  27.900         0    yes  16884.92400                 0
# 1   18    male  33.770         1     no   1725.55230                 0
# 2   28    male  33.000         3     no   4449.46200                 0
# 3   33    male  22.705         0     no  21984.47061                 1
# 4   32    male  28.880         0     no   3866.85520                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
df1=pd.get_dummies(df['region'],prefix='region')
df= pd.concat([df,df1], axis=1).drop(['region'],axis=1)
df.head()
# Out:
#    age     sex     bmi  children smoker      charges  region_northeast  \
# 0   19  female  27.900         0    yes  16884.92400                 0
# 1   18    male  33.770         1     no   1725.55230                 0
# 2   28    male  33.000         3     no   4449.46200                 0
# 3   33    male  22.705         0     no  21984.47061                 0
# 4   32    male  28.880         0     no   3866.85520                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %% [markdown]
# - if drop_first=True is not given then region_nortwest will as be shown in the output
# - but it's not needed as the one which does not come under any of the three region will absolutely be the in the 4th region
# - so, there is no need to waste another column on it

# %% [markdown]
# ### handling smoker

# %%
df2=pd.get_dummies(df['smoker'], prefix='smoker',drop_first=True)
df= pd.concat([df,df2], axis=1).drop(['smoker'],axis=1)
df

# drop first = True will drop smoker_no column
# Out:
#       age     sex     bmi  children      charges  region_northwest  \
# 0      19  female  27.900         0  16884.92400                 0
# 1      18    male  33.770         1   1725.55230                 0
# 2      28    male  33.000         3   4449.46200                 0
# 3      33    male  22.705         0  21984.47061                 1
# 4      32    male  28.880         0   3866.85520                 1
# ...   ...     ...     ...       ...          ...               ...
# 1333   50    male  30.970         3  10600.54830                 1
# 1334   18  female  31.920         0   2205.98080                 0
# 1335   18  female  36.850         0   1629.83350                 0
# 1336   21  female  25.800         0   2007.94500                 0
# 1337   61  female  29.070         0  29141.36030                 1
#
#       region_southeast  region_southwest  smoker_yes
# 0                    0                 1           1
# 1                    1                 0           0
# ...

# %% [markdown]
# ### handling sex

# %%
df3=pd.get_dummies(df['sex'], prefix='sex',drop_first=True)
df= pd.concat([df,df3], axis=1).drop(['sex'],axis=1)

# %%
df
# Out:
#       age     bmi  children      charges  region_northwest  region_southeast  \
# 0      19  27.900         0  16884.92400                 0                 0
# 1      18  33.770         1   1725.55230                 0                 1
# 2      28  33.000         3   4449.46200                 0                 1
# 3      33  22.705         0  21984.47061                 1                 0
# 4      32  28.880         0   3866.85520                 1                 0
# ...   ...     ...       ...          ...               ...               ...
# 1333   50  30.970         3  10600.54830                 1                 0
# 1334   18  31.920         0   2205.98080                 0                 0
# 1335   18  36.850         0   1629.83350                 0                 1
# 1336   21  25.800         0   2007.94500                 0                 0
# 1337   61  29.070         0  29141.36030                 1                 0
#
#       region_southwest  smoker_yes  sex_male
# ...

# %% [markdown]
# ## METHOD 4 -  using .loc[ ] function

# %% [raw]
# # The algorithm can only understand numbers hence conversion of categorical
# # data is important.The first way can be using EDA and domain knowledge
# # and by applying loc function
# # Why particluar value is taken,reason should be proper.
#
# df.loc[df[columns]=='',columns]='some numerical value'

# %% [markdown]
# ### handling region

# %%
df=pd.read_csv('insurance.csv')

# %%
df.loc[df['region']=='southwest','region']=0
df.loc[df['region']=='southeast','region']=1
df.loc[df['region']=='northwest','region']=2
df.loc[df['region']=='northeast','region']=3

# %% [markdown]
# ### handling smoker

# %%
df.loc[df['smoker']=='yes','smoker']=1
df.loc[df['smoker']=='no','smoker']=0

# %% [markdown]
# ### handling sex

# %%
df.loc[df['sex']=='male','sex']=1
df.loc[df['sex']=='female','sex']=0

# %%
df
# Out:
#       age sex     bmi  children smoker region      charges
# 0      19   0  27.900         0      1      0  16884.92400
# 1      18   1  33.770         1      0      1   1725.55230
# 2      28   1  33.000         3      0      1   4449.46200
# 3      33   1  22.705         0      0      2  21984.47061
# 4      32   1  28.880         0      0      2   3866.85520
# ...   ...  ..     ...       ...    ...    ...          ...
# 1333   50   1  30.970         3      0      2  10600.54830
# 1334   18   0  31.920         0      0      3   2205.98080
# 1335   18   0  36.850         0      0      1   1629.83350
# 1336   21   0  25.800         0      0      0   2007.94500
# 1337   61   0  29.070         0      1      2  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## NOTE
# - method 4 is mostly preferred as it is easy compared to method 3
# - I have used method 3 here, lets see the accuracy
# - if the accuracy is not good enough, we can change back to method1 or 2 or 4

# %% [markdown]
# ## IMP NOTE
# - the accuracy of the prediction depends on the method we use( label encoding, one hor encoding, using get_dummies(), using .loc[])
# - this is where we use try and error method
# - we try with one method and if the accuracy is low then we go with another method

# %% [markdown]
# ## STEP 5 - FEATURE SELECTION
# - 1) checking for correlation using heatmap
# - 2) checking for constant columns
# - 3) checking for duplicate rows - 3rd step in feature selection
# - if the same row is being repeated two or more times, then they have to be removed
# - they can be identified using data.duplicated().sum() function

# %% [markdown]
# ### CHECKING FOR CORELATION USING HEATMAP( )

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, cmap='cool')
plt.show()

# %% [markdown]
# ### CHECKING FOR CONSTANT COLUMNS

# %%
df.describe()
# Out:
#                age          bmi     children       charges  region_northwest  \
# count  1338.000000  1338.000000  1338.000000   1338.000000       1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265          0.242900
# std      14.049960     6.098187     1.205493  12110.011237          0.428995
# min      18.000000    15.960000     0.000000   1121.873900          0.000000
# 25%      27.000000    26.296250     0.000000   4740.287150          0.000000
# 50%      39.000000    30.400000     1.000000   9382.033000          0.000000
# 75%      51.000000    34.693750     2.000000  16639.912515          0.000000
# max      64.000000    53.130000     5.000000  63770.428010          1.000000
#
#        region_southeast  region_southwest   smoker_yes     sex_male
# count       1338.000000       1338.000000  1338.000000  1338.000000
# mean           0.272048          0.242900     0.204783     0.505232
# std            0.445181          0.428995     0.403694     0.500160
# ...

# %% [markdown]
# - as standard deviation is not zero for any column, we can conclude there are no constant columns

# %% [markdown]
# ### CHECKING FOR DUPLICATE ROWS

# %%
df.duplicated().sum()
# so there is only one duplicate row
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)
# Iinplace=True will make the changes permanent

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## STEP 6 - MODEL BUILDING

# %% [markdown]
# ## LINEAR REGRESSION

# %% [markdown]
# ### SETP A) DIVIDING DATA INTO DEPENDENT AND INDEPENDENT VARIABLES

# %% [markdown]
# - as we are trying to predict the charge of the insurance, charge will be the dependent variable
# - and all the other variables are independent variables

# %%
x=df.drop(['charges'],axis=1)
y=df['charges']

# %%
x
# Out:
#       age     bmi  children  region_northwest  region_southeast  \
# 0      19  27.900         0                 0                 0
# 1      18  33.770         1                 0                 1
# 2      28  33.000         3                 0                 1
# 3      33  22.705         0                 1                 0
# 4      32  28.880         0                 1                 0
# ...   ...     ...       ...               ...               ...
# 1333   50  30.970         3                 1                 0
# 1334   18  31.920         0                 0                 0
# 1335   18  36.850         0                 0                 1
# 1336   21  25.800         0                 0                 0
# 1337   61  29.070         0                 1                 0
#
#       region_southwest  smoker_yes  sex_male
# 0                    1           1         0
# 1                    0           0         1
# 2                    0           0         1
# ...

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %% [markdown]
# ### STEP B) SPLITTING THE DATA INTO TRAIN AND TEST
# - for this we need to use a package called train_test_split
# - this is available in sklearn.model_selection

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# - the order should be x_train, x_test, y_train, y_test
# - this order should not be changed
# - as we gave test_size=0.2, train size will automatically be 0.8
# - random_state=42, means that, it selects 42 random rows from train and test

# %%
x_train.shape
# Out:
# (1069, 8)

# %%
x_test.shape
# Out:
# (268, 8)

# %%
y_train.shape
# Out:
# (1069,)

# %%
y_test.shape
# Out:
# (268,)

# %% [markdown]
# ### STEP C) IMPORTING THE ALGORITHM PACKAGE
# ### STEP D) CREATING A OBJECT FOR THE ALGORITHM
# - that is giving a name to the algorithm

# %%
from sklearn.linear_model import LinearRegression # importing the algorithm package
Lin_reg = LinearRegression()  # creating the object for the algorithm

# %% [markdown]
# ### STEP E) LOADING THE TRAINING DATA INTO ALGORITHM
# - we have .fit() function for loading the training data

# %%
Lin_reg.fit(x_train, y_train) #Training the model
# Out:
# LinearRegression()

# %% [markdown]
# ## NOTE
# - as we know that linear regression works on line equation, we can check the y-intercept and slope value
# - this step of checking the m and c value is optional

# %%
print(Lin_reg.intercept_) #C value in Equation of line
print(Lin_reg.coef_) #coefficients of x (m value)
# Out:
# -11092.652295945947
# [  248.21072022   318.70144095   533.0099888   -391.76145478
#   -838.91961573  -659.13975155 23077.76459287  -101.54205399]

# %% [markdown]
# ## STEP 7 - MODEL EVALUATION AND CHECKING PERFORMANCES
# - we will check for the accuracy of the training using the performance metrics( that is r2_score, mean_squared_error, mean_absolute_error )
# - all the performance metrices are available in sklearn.metrics packages

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %% [markdown]
# ### NOTE
# - to calculate the performance metrics( that is r2_score, mean_squared_error, mean_absolute_error ) we need the predicted value
# - hence we need to calculate the predicted value first

# %% [markdown]
# ## calculating the predicted value
# - we use .predict() function for this
# - this generates the predicted value using the actual value

# %%
y_train_predict=Lin_reg.predict(x_train) 

#We are using X_Train to predict Y_train

# %% [markdown]
# - now we can calculate the performance metrics

# %% [markdown]
# ### CALCULATING R2_SCORE

# %%
train_score=r2_score(y_train,y_train_predict) #r2 score for training data
print("The Training Accuracy is :",train_score*100,'%')
# Out:
# The Training Accuracy is : 72.99057809339075 %

# %% [markdown]
# ### CALCULATING ADJUSTED R2_SCORE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_train.shape
# Out:
# (1069, 8)

# %%
train_adjusted_r2 = 1-((1-train_score)*(1069-1))/(1069-8-1)
print("The Adjusted r2 Accuracy is: ",(train_adjusted_r2*100),"%")
# Out:
# The Adjusted r2 Accuracy is:  72.78673339975596 %

# %% [markdown]
# - so the machine has learned 72.78% of the training data
# - actually 72 % is not enough
# - adjusted r2_score value will always be less than r2_score value

# %% [markdown]
# ### NOW WE NEED TO CHECK HOW WELL IT IS PREDICTING THE OUTPUT
# - that is calculating the testing accuracy
# - in in the calculation of training accuracy we calculated the y_train_predict by using x_train
# - but here we will calculate y_test_predict using x_test
# ### Model Evaluation - prediciton on test data

# %% [markdown]
# ### CALCULATING R2_SCORE

# %%
y_test_predict=Lin_reg.predict(x_test) #Using x_test to predict y_test 
test_score=r2_score(y_test,y_test_predict) #R2 score for testing data
print("The Testing Accuracy is: ",(test_score*100),"%")
# Out:
# The Testing Accuracy is:  80.69287081198013 %

# %%
x_test.shape
# Out:
# (268, 8)

# %% [markdown]
# ### CALCULATING ADJUSTED R2_SCORE

# %%
test_adjusted_r2 = 1-((1-test_score)*(268-1))/(268-8-1)
print("The Accuracy using Adjusted R2 is :",(test_adjusted_r2*100),"%")
# Out:
# The Accuracy using Adjusted R2 is : 80.09651160926137 %

# %% [markdown]
# - 80% is not enough for acceptaning the model, we will have to tune it more

# %% [markdown]
# ## CALCULATING ERREORS

# %%
import math
print(mean_squared_error(y_test,y_test_predict))
print()
print(math.sqrt(mean_squared_error(y_test,y_test_predict))) # root mean squared error
# the lower this value, that means the better the model coukd predict
print()
print(mean_absolute_error(y_test,y_test_predict))
# Out:
# 35478020.6752356
#
# 5956.342894363587
#
# 4177.045561036319

# %% [markdown]
# ## NOTE

# %% [markdown]
# **Assumptions of Linear Regression:**<br>
#     - Linearity: Linear relationship exist between dependent and independent variable. In case of non-linearity, use transformation such as logarthmic, exponential, square root etc <br>
#     - No multicollinearity: If there is multicollinearity its unclear which independent variable explains the dependent variable. <br>
#     - Errors are normally distributed. If not, then confidence interval may become too wide or narrow.
#
# **Pros:**<br>
#     - Simple method<br>
#     - Easy to use and understand<br>
#
# **Cons**<br>
#     - Very sensitive to outliers : often leads to model with low accuracy<br>
#     - It performs well for linearly seperable datasets. So not recommended for most real world applications as it produces simplified results assuming linear relationship between the data.
